# %% [markdown]
# ## Plotten; Symbolische Aktionen; Zwei Ableitungen

# %%
# %config InlineBackend.figure_format = 'retina' # erhöht die Auflösung der plots
from sympy import *
init_printing()
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
from IPython.display import display, Math

# %%
def ableitungen(term):
    term_d = diff (term, x)
    term_dd = diff (term_d, x)    
    return term_d, term_dd

def functions(term):
    f = Lambda(x,term)(x)
    term_d, term_dd = ableitungen(term)
    g = Lambda(x,term_d)(x)
    h = Lambda(x,term_dd)(x)
    return f, g, h, term_d, term_dd
    
def plotFkt(term, ugx, ogx, ugy, ogy):
    f, g, h, term_d, term_dd = functions(term)
    p1=plot(f,(x,ugx,ogx),show=False)
    p2=plot(g,(x,ugx,ogx),show=False)
    p3=plot(h,(x,ugx,ogx),show=False)
    p1.extend(p2)
    p1.extend(p3)
    p1.legend=True
    
    fl = "$" + "f(x) = " + latex(term) + "$"
    
    fdl = "$" + "f^{\prime}(x) = " + latex(term_d) + "$"

    fddl = "$" + "f^{\prime\prime}(x) = " + latex(term_dd) + "$"
    
    p1[0].label = fl
    p1[1].label = fdl
    p1[2].label = fddl
    
    p1[1].line_color='red'
    p1[2].line_color='green'
    
    p1.ylim=(ugy, ogy)
    p1.show() 
    
    display (Math (latex(fl)))
    display (Math (latex(fdl)))
    display (Math (latex(fddl)))

# %%
x=Symbol('x')
plotFkt (x**3 + 2*x**2 - 3*x + 4, -5, 4, -30, 30)
plotFkt (sin(x)/x, -7, 7, -1.2, 1.2)
plotFkt (x*sin(x), -7, 7, -10, 10)
plotFkt (1/(1+exp(-x)), -5, 7, -0.5, 1.2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# $\displaystyle \mathtt{\text{\$f(x) = x\textasciicircum\{3\} + 2 x\textasciicircum\{2\} - 3 x + 4\$}}$
# $\displaystyle \mathtt{\text{\$f\textasciicircum\{\textbackslashprime\}(x) = 3 x\textasciicircum\{2\} + 4 x - 3\$}}$
# $\displaystyle \mathtt{\text{\$f\textasciicircum\{\textbackslashprime\textbackslashprime\}(x) = 6 x + 4\$}}$
# <img src="data:image/png;base64,..." width="640">
# $\displaystyle \mathtt{\text{\$f(x) = \textbackslashfrac\{\textbackslashsin\{\textbackslashleft(x \textbackslashright)\}\}\{x\}\$}}$
# $\displaystyle \mathtt{\text{\$f\textasciicircum\{\textbackslashprime\}(x) = \textbackslashfrac\{\textbackslashcos\{\textbackslashleft(x \textbackslashright)\}\}\{x\} - \textbackslashfrac\{\textbackslashsin\{\textbackslashleft(x \textbackslashright)\}\}\{x\textasciicircum\{2\}\}\$}}$
# $\displaystyle \mathtt{\text{\$f\textasciicircum\{\textbackslashprime\textbackslashprime\}(x) = - \textbackslashfrac\{\textbackslashsin\{\textbackslashleft(x \textbackslashright)\}\}\{x\} - \textbackslashfrac\{2 \textbackslashcos\{\textbackslashleft(x \textbackslashright)\}\}\{x\textasciicircum\{2\}\} + \textbackslashfrac\{2 \textbackslashsin\{\textbackslashleft(x \textbackslashright)\}\}\{x\textasciicircum\{3\}\}\$}}$
# <img src="data:image/png;base64,..." width="640">
# $\displaystyle \mathtt{\text{\$f(x) = x \textbackslashsin\{\textbackslashleft(x \textbackslashright)\}\$}}$
# $\displaystyle \mathtt{\text{\$f\textasciicircum\{\textbackslashprime\}(x) = x \textbackslashcos\{\textbackslashleft(x \textbackslashright)\} + \textbackslashsin\{\textbackslashleft(x \textbackslashright)\}\$}}$
# $\displaystyle \mathtt{\text{\$f\textasciicircum\{\textbackslashprime\textbackslashprime\}(x) = - x \textbackslashsin\{\textbackslashleft(x \textbackslashright)\} + 2 \textbackslashcos\{\textbackslashleft(x \textbackslashright)\}\$}}$
# <img src="data:image/png;base64,..." width="640">
# $\displaystyle \mathtt{\text{\$f(x) = \textbackslashfrac\{1\}\{1 + e\textasciicircum\{- x\}\}\$}}$
# $\displaystyle \mathtt{\text{\$f\textasciicircum\{\textbackslashprime\}(x) = \textbackslashfrac\{e\textasciicircum\{- x\}\}\{\textbackslashleft(1 + e\textasciicircum\{- x\}\textbackslashright)\textasciicircum\{2\}\}\$}}$
# $\displaystyle \mathtt{\text{\$f\textasciicircum\{\textbackslashprime\textbackslashprime\}(x) = - \textbackslashfrac\{e\textasciicircum\{- x\}\}\{\textbackslashleft(1 + e\textasciicircum\{- x\}\textbackslashright)\textasciicircum\{2\}\} + \textbackslashfrac\{2 e\textasciicircum\{- 2 x\}\}\{\textbackslashleft(1 + e\textasciicircum\{- x\}\textbackslashright)\textasciicircum\{3\}\}\$}}$
